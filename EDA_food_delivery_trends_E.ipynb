# %% [markdown]
# ### <center>**CONFIGURING LIBRARY IMPORTS📚**</center>

# %%
# Managing Data.
import pandas as pd
import numpy as np
import re
# -----------------------------------------------------------------------

# Evaluating the distribution of the relationship between variables.
import scipy.stats as stats
from scipy.stats import ttest_ind, norm, chi2_contingency, f_oneway
from scipy.stats import shapiro, kstest, poisson, chisquare, expon

# -----------------------------------------------------------------------

# Imputing nulls using advanced statistical methods.
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.linear_model import LinearRegression

# -----------------------------------------------------------------------

# Visualisation libraries.
import seaborn as sns
import matplotlib.pyplot as plt

# -----------------------------------------------------------------------

# Managing warnings.
import warnings
warnings.filterwarnings("ignore")

# -----------------------------------------------------------------------

# Configuration: Checking the setting of the display to its maximum capacity to better show the dataframe.
pd.set_option('display.max_rows', None)  # Cambia el número máximo de filas mostradas
pd.set_option('display.max_columns', None)  # Cambia el número máximo de columnas mostradas para poder visualizar todas las columnas del DF
pd.set_option('display.width', None)  # Cambia el ancho máximo de la pantalla

# %% [markdown]
# ### <center>**CSV DOCUMENT READING📂**</center>

# %%
# Opening/Reading the csv document as a DataFrame to start the process of exploration and analysis of the data.
df_onlinefoods = pd.read_csv("onlinefoods.csv")

# %% [markdown]
# ### <center>**🔎EXPLORATORY DATA ANALYSIS (EDA)🔍**</center>
# ### <center>**PANDAS METHODS🐼**</center>

# %%
# Displaying the first 5 rows of the dataset (default is 5 rows).
df_onlinefoods.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# 4    Yes   Positive         Yes

# %%
# Displaying the last 5 rows of the dataset (default is 5 rows).
df_onlinefoods.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# 386    Yes  Positive         Yes
# 387    Yes  Positive         Yes

# %%
# Displaying a summary of the dataset, including data types, non-null counts, and memory usage.
df_onlinefoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 39.5+ KB

# %%
# Printing a random sample of 5 entries to check the information displayed in each column.
df_onlinefoods.sample(5)
# Out:
#      Age Gender Marital Status Occupation Monthly Income  \
# 256   23   Male         Single    Student      No Income
# 190   24   Male         Single    Student      No Income
# 340   23   Male         Single    Student      No Income
# 87    25   Male         Single    Student      No Income
# 107   25   Male         Single    Student      No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 256              Post Graduate            2   12.9770    77.5773    560009
# 190              Post Graduate            3   13.0487    77.5923    560024
# 340                   Graduate            3   13.0223    77.7132    560049
# 87                    Graduate            1   12.9770    77.5773    560009
# 107              Post Graduate            1   12.9343    77.6044    560029
#
#     Output   Feedback Unnamed: 12
# 256     No  Negative           No
# 190     No  Negative           No
# 340    Yes   Positive         Yes
# 87     Yes   Positive         Yes
# 107    Yes   Positive         Yes

# %%
# Checking the number of rows and columns in several ways:

# Method 1: len(df) gives the number of rows, len(df.columns) gives the number of columns
print(len(df_onlinefoods))
print(len(df_onlinefoods.columns))

# Method 2: .shape attribute to display the number of rows and columns separately
print(f"Number of rows: {df_onlinefoods.shape[0]}\nNumber of columns: {df_onlinefoods.shape[1]}")

# Method 3: .shape attribute provides a tuple (rows, columns)
df_onlinefoods.shape
# Out:
# 388
# 13
# Number of rows: 388
# Number of columns: 13
# (388, 13)

# %%
# Printing the name of the columns separately.
df_onlinefoods.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
# Displaying descriptive statistics for numerical columns in the dataset.
df_onlinefoods.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
# Displaying descriptive statistics for object columns in the dataset.
df_onlinefoods.describe(include = "object").T
# Out:
#                            count unique        top freq
# Gender                       388      2       Male  222
# Marital Status               388      3     Single  268
# Occupation                   388      4    Student  207
# Monthly Income               388      5  No Income  187
# Educational Qualifications   388      5   Graduate  177
# Output                       388      2        Yes  301
# Feedback                     388      2   Positive  317
# Unnamed: 12                  388      2        Yes  301

# %%
# Printing the names of the numeric columns.
numeric_columns = df_onlinefoods.select_dtypes(include = np.number).columns
numeric_columns
# Out:
# Index(['Age', 'Family size', 'latitude', 'longitude', 'Pin code'], dtype='object')

# %%
# Printing the names of the object columns.
string_columns = df_onlinefoods.select_dtypes(include = "object").columns
string_columns
# Out:
# Index(['Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %% [markdown]
# ### <center>**VALUES**</center>

# %% [markdown]
# Printing out the counts of unique values in a Series, sorted in descending order of each column composing the Dataset to know both the unique values and their frequency of occurrence.

# %%
df_onlinefoods['Age'].value_counts()
# Out:
# Age
# 23    73
# 22    57
# 25    52
# 24    50
# 26    35
# 21    23
# 27    21
# 32    16
# 28    15
# 29    14
# 20     9
# 30     9
# 31     8
# 19     4
# 18     1
# 33     1
# Name: count, dtype: int64

# %%
df_onlinefoods['Gender'].value_counts()
# Out:
# Gender
# Male      222
# Female    166
# Name: count, dtype: int64

# %%
df_onlinefoods['Marital Status'].value_counts()
# Out:
# Marital Status
# Single               268
# Married              108
# Prefer not to say     12
# Name: count, dtype: int64

# %%
df_onlinefoods['Occupation'].value_counts()
# Out:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64

# %%
df_onlinefoods['Monthly Income'].value_counts()
# Out:
# Monthly Income
# No Income          187
# 25001 to 50000      69
# More than 50000     62
# 10001 to 25000      45
# Below Rs.10000      25
# Name: count, dtype: int64

# %%
df_onlinefoods['Educational Qualifications'].value_counts()
# Out:
# Educational Qualifications
# Graduate         177
# Post Graduate    174
# Ph.D              23
# School            12
# Uneducated         2
# Name: count, dtype: int64

# %%
df_onlinefoods['Family size'].value_counts()
# Out:
# Family size
# 3    117
# 2    101
# 4     63
# 5     54
# 6     29
# 1     24
# Name: count, dtype: int64

# %%
df_onlinefoods['latitude'].value_counts()
# Out:
# latitude
# 12.9770    36
# 12.9783    16
# 12.9850    14
# 12.8845    12
# 12.9261    11
# 12.9369    11
# 12.9048     9
# 12.9706     9
# 12.9343     8
# 13.0487     8
# 12.9766     8
# 12.9698     8
# 13.0206     8
# 13.0103     8
# 13.0626     7
# 12.9570     7
# 12.9337     7
# 13.0158     7
# 13.0019     7
# 12.9980     6
# 12.9551     6
# 12.9306     6
# 12.9561     6
# 12.9635     6
# 12.9925     6
# 12.9217     6
# 12.9820     6
# 12.9757     5
# 13.0641     5
# 12.9889     5
# 13.0138     5
# 12.9442     5
# 12.9299     5
# 12.9438     5
# 12.9828     5
# 12.8988     5
# 12.9149     4
# 12.8893     4
# 12.9854     4
# 13.0140     4
# 13.0012     4
# 12.9579     4
# 13.0734     4
# 12.9967     4
# 12.9847     4
# 12.9859     4
# 13.0289     3
# 12.9037     3
# 12.9662     3
# 13.0166     3
# 12.9335     2
# 13.1020     2
# 12.8834     2
# 12.9105     2
# 12.9515     2
# 13.0067     2
# 12.9119     2
# 13.0223     2
# 13.0503     2
# 13.0298     2
# 13.0809     2
# 12.9866     2
# 13.0078     2
# 13.0262     2
# 12.9473     2
# 12.9890     1
# 12.9251     1
# 12.8652     1
# 12.9621     1
# 12.9537     1
# 13.0496     1
# 12.9883     1
# 12.9565     1
# 12.9983     1
# 12.9353     1
# 12.9155     1
# 12.9719     1
# Name: count, dtype: int64

# %%
df_onlinefoods['longitude'].value_counts()
# Out:
# longitude
# 77.5773    36
# 77.6408    16
# 77.5533    14
# 77.6036    12
# 77.6221    11
# 77.6407    11
# 77.6529     9
# 77.6821     9
# 77.6044     8
# 77.6479     8
# 77.5923     8
# 77.5796     8
# 77.7500     8
# 77.5993     8
# 77.5713     7
# 77.5900     7
# 77.5284     7
# 77.5637     7
# 77.5390     7
# 77.5633     6
# 77.5434     6
# 77.6256     6
# 77.5821     6
# 77.6227     6
# 77.5921     6
# 77.5936     6
# 77.6593     6
# 77.5738     5
# 77.5764     5
# 77.6076     5
# 77.5931     5
# 77.5586     5
# 77.6848     5
# 77.5877     5
# 77.5741     5
# 77.6131     5
# 77.6399     4
# 77.5635     4
# 77.5464     4
# 77.5376     4
# 77.5995     4
# 77.7582     4
# 77.5658     4
# 77.6309     4
# 77.5491     4
# 77.6713     4
# 77.7081     4
# 77.6804     3
# 77.5400     3
# 77.6068     3
# 77.5565     2
# 77.4904     2
# 77.5864     2
# 77.5450     2
# 77.5691     2
# 77.5529     2
# 77.7132     2
# 77.6446     2
# 77.6200     2
# 77.5616     2
# 77.4921     2
# 77.5486     2
# 77.5577     2
# 77.6047     2
# 77.4842     2
# 77.6176     1
# 77.5332     1
# 77.4992     1
# 77.4941     1
# 77.5135     1
# 77.5240     1
# 77.5987     1
# 77.5484     1
# 77.6409     1
# 77.5585     1
# 77.5128     1
# Name: count, dtype: int64

# %%
df_onlinefoods['Pin code'].value_counts()
# Out:
# Pin code
# 560009    36
# 560038    16
# 560010    14
# 560076    12
# 560034    11
# 560095    11
# 560036     9
# 560075     9
# 560029     8
# 560024     8
# 560001     8
# 560066     8
# 560043     8
# 560080     8
# 560015     7
# 560018     7
# 560011     7
# 560096     7
# 560003     7
# 560005     6
# 560017     6
# 560085     6
# 560027     6
# 560002     6
# 560021     6
# 560041     6
# 560008     6
# 560023     5
# 560092     5
# 560020     5
# 560006     5
# 560030     5
# 560103     5
# 560004     5
# 560042     5
# 560078     5
# 560070     4
# 560068     4
# 560048     4
# 560012     4
# 560046     4
# 560007     4
# 560014     4
# 560067     4
# 560100     4
# 560093     4
# 560022     3
# 560061     3
# 560025     3
# 560016     3
# 560028     2
# 560064     2
# 560062     2
# 560060     2
# 560056     2
# 560086     2
# 560102     2
# 560049     2
# 560013     2
# 560032     2
# 560097     2
# 560091     2
# 560055     2
# 560045     2
# 560019     2
# 560079     1
# 560059     1
# 560109     1
# 560104     1
# 560047     1
# 560073     1
# 560051     1
# 560026     1
# 560033     1
# 560050     1
# 560098     1
# 560072     1
# Name: count, dtype: int64

# %%
df_onlinefoods['Output'].value_counts()
# Out:
# Output
# Yes    301
# No      87
# Name: count, dtype: int64

# %%
df_onlinefoods['Feedback'].value_counts()
# Out:
# Feedback
# Positive     317
# Negative      71
# Name: count, dtype: int64

# %%
df_onlinefoods['Unnamed: 12'].value_counts()
# Out:
# Unnamed: 12
# Yes    301
# No      87
# Name: count, dtype: int64

# %% [markdown]
# Printing out an unordered array of unique values in a Series, of each column composing the Dataset.

# %%
df_onlinefoods['Age'].unique()
# Out:
# array([20, 24, 22, 27, 23, 21, 28, 25, 32, 30, 31, 26, 18, 19, 33, 29])

# %%
df_onlinefoods['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df_onlinefoods['Marital Status'].unique()
# Out:
# array(['Single', 'Married', 'Prefer not to say'], dtype=object)

# %%
df_onlinefoods['Occupation'].unique()
# Out:
# array(['Student', 'Employee', 'Self Employeed', 'House wife'],
#       dtype=object)

# %%
df_onlinefoods['Monthly Income'].unique()
# Out:
# array(['No Income', 'Below Rs.10000', 'More than 50000', '10001 to 25000',
#        '25001 to 50000'], dtype=object)

# %%
df_onlinefoods['Educational Qualifications'].unique()
# Out:
# array(['Post Graduate', 'Graduate', 'Ph.D', 'Uneducated', 'School'],
#       dtype=object)

# %%
df_onlinefoods['Family size'].unique()
# Out:
# array([4, 3, 6, 2, 5, 1])

# %%
df_onlinefoods['latitude'].unique()
# Out:
# array([12.9766, 12.977 , 12.9551, 12.9473, 12.985 , 12.9299, 12.9828,
#        12.9854, 12.8988, 12.9438, 12.8893, 12.9783, 12.982 , 13.0298,
#        12.9983, 12.9925, 12.9306, 12.9353, 12.9155, 13.0019, 12.9698,
#        12.9261, 12.9119, 12.9662, 12.9565, 13.0206, 12.9635, 13.0067,
#        12.8845, 13.0158, 12.9343, 13.0012, 12.9442, 13.0487, 12.9889,
#        12.9335, 13.102 , 12.9048, 12.9337, 12.9037, 13.0289, 12.9561,
#        12.9579, 13.014 , 13.0138, 12.9537, 12.998 , 13.0496, 13.0166,
#        13.0503, 12.9883, 13.0626, 12.957 , 12.8652, 12.9757, 12.9621,
#        12.9217, 13.0223, 13.0262, 13.0078, 12.9105, 12.8834, 12.9149,
#        12.9706, 13.0103, 13.0641, 12.9369, 13.0809, 12.9859, 12.9866,
#        12.9847, 12.989 , 12.9251, 12.9967, 13.0734, 12.9515, 12.9719])

# %%
df_onlinefoods['longitude'].unique()
# Out:
# array([77.5993, 77.5773, 77.6593, 77.5616, 77.5533, 77.6848, 77.6131,
#        77.7081, 77.5764, 77.5738, 77.6399, 77.6408, 77.6256, 77.6047,
#        77.6409, 77.5633, 77.5434, 77.5585, 77.5135, 77.5713, 77.75  ,
#        77.6221, 77.6446, 77.6068, 77.5484, 77.6479, 77.5821, 77.545 ,
#        77.6036, 77.539 , 77.6044, 77.5995, 77.6076, 77.5923, 77.5741,
#        77.5691, 77.5864, 77.6821, 77.59  , 77.5376, 77.54  , 77.5921,
#        77.6309, 77.5658, 77.5877, 77.6176, 77.6227, 77.4941, 77.6804,
#        77.5529, 77.5987, 77.5284, 77.5637, 77.524 , 77.5586, 77.5936,
#        77.7132, 77.62  , 77.5577, 77.4842, 77.5486, 77.5635, 77.6529,
#        77.5796, 77.5931, 77.6407, 77.5565, 77.6713, 77.4904, 77.5491,
#        77.5332, 77.4992, 77.7582, 77.5464, 77.4921, 77.5128])

# %%
df_onlinefoods['Pin code'].unique()
# Out:
# array([560001, 560009, 560017, 560019, 560010, 560103, 560042, 560048,
#        560078, 560004, 560068, 560038, 560008, 560032, 560033, 560021,
#        560085, 560050, 560098, 560003, 560066, 560034, 560102, 560025,
#        560026, 560043, 560002, 560086, 560076, 560096, 560029, 560046,
#        560030, 560024, 560020, 560028, 560064, 560036, 560011, 560061,
#        560022, 560027, 560007, 560012, 560006, 560047, 560005, 560073,
#        560016, 560013, 560051, 560015, 560018, 560109, 560023, 560104,
#        560041, 560049, 560045, 560055, 560060, 560062, 560070, 560075,
#        560080, 560092, 560095, 560097, 560093, 560091, 560100, 560079,
#        560059, 560067, 560014, 560056, 560072])

# %%
df_onlinefoods['Output'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_onlinefoods['Feedback'].unique()
# Out:
# array(['Positive', 'Negative '], dtype=object)

# %%
df_onlinefoods['Unnamed: 12'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ### <center>**DUPLICATES**</center>

# %%
# Checking duplicates.
duplicates = df_onlinefoods.duplicated().sum()
duplicates
# Out:
# 103

# %% [markdown]
# ### <center>**NULLS**</center>

# %%
# Checking nulls.
nulls = df_onlinefoods.isnull().sum()
nulls
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %% [markdown]
# #### **<span style="color:#FFFF00">EDA Observations**</span>

# %% [markdown]
# **- Columns' names:** ['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12']
#
# **- Numerical columns' names:** ['Age', 'Family size', 'latitude', 'longitude', 'Pin code']
#
# **- Object columns' names:** ['Gender', 'Marital Status', 'Occupation', 'Monthly Income', 'Educational Qualifications', 'Output', 'Feedback', 'Unnamed: 12']
#
# **- No nulls**
#
# **- Types of data included in Dataset & number of columns containing that type:** float64(2), int64(3), object(8)

# %% [markdown]
# #### **<span style="color:#FFFF00">Transformation suggestions**</span>

# %% [markdown]
# - Column **['Unnamed: 12']** is unclear what type of information it contains, decision is for column to be dropped.

# %%
# Transformation to eliminate column ['Unnamed: 12'].

df_onlinefoods.drop(columns = 'Unnamed: 12', inplace=True)

# %% [markdown]
# - Column **['Monthly Income']** contains both text and numerical data, but the currency is unclear. Thus, it is decided we will change this to the internationally-known code INR, as well as include text for those two categories starting as a number.
#
# (['No Income', 'Below Rs.10000', 'More than 50000', '10001 to 25000', '25001 to 50000'], dtype=object)

# %%
# Transformation to modify Rs. to the internationally-known code: INR

df_onlinefoods['Monthly Income'] = df_onlinefoods['Monthly Income'].replace({
    'No Income': 'No Income',
    'Below Rs.10000': 'Below 10000 INR',
    'More than 50000': 'More than 50000 INR',
    '10001 to 25000': 'Between 10001 and 25000 INR',
    '25001 to 50000': 'Between 25001 and 50000 INR'
})

# %% [markdown]
# - Column **['Output']** contains two types of values, which are object type. However, these should be boolean.

# %%
# Transformation to change the type of data from object to boolean.

df_onlinefoods['Output'] = df_onlinefoods['Output'].replace({'Yes': True, 'No': False})

# %% [markdown]
# -  Columns names are capitalized except for **['latitude']** and ['longitude'] and include a space between two strings of text. My suggestion would be to rename the columns so that they are all written in lowercase and spaces are replaced by a _.

# %%
# Transformation of columns' names by converting them to lowercase and replacing spaces with underscores.

def standardise_column_names(df):
    df.columns = [col.lower().replace(" ", "_") for col in df.columns]
    return df

# %% [markdown]
# #### **<span style="color:#FFFF00">Verification of applied changes**</span>

# %%
df_onlinefoods["monthly_income"].unique()
# Out:
# array(['No Income', 'Below 10000 INR', 'More than 50000 INR',
#        'Between 10001 and 25000 INR', 'Between 25001 and 50000 INR'],
#       dtype=object)

# %%
df_onlinefoods['output'].unique()
# Out:
# array([ True, False])

# %%
standardise_column_names(df_onlinefoods)
# Out:
#      age  gender     marital_status      occupation  \
# 0     20  Female             Single         Student
# 1     24  Female             Single         Student
# 2     22    Male             Single         Student
# 3     22  Female             Single         Student
# 4     22    Male             Single         Student
# 5     27  Female            Married        Employee
# 6     22    Male             Single         Student
# 7     24  Female             Single         Student
# 8     23  Female             Single         Student
# 9     23  Female             Single         Student
# 10    22  Female             Single         Student
# 11    23    Male             Single         Student
# 12    23    Male             Single         Student
# 13    21    Male             Single         Student
# 14    23  Female             Single  Self Employeed
# 15    24  Female             Single         Student
# 16    28  Female             Single        Employee
# 17    23  Female             Single         Student
# 18    25    Male             Single         Student
# 19    21  Female             Single         Student
# 20    24    Male             Single         Student
# 21    22    Male             Single         Student
# 22    22  Female             Single         Student
# 23    23    Male             Single         Student
# 24    21    Male             Single         Student
# 25    25    Male             Single         Student
# 26    22  Female             Single         Student
# 27    22    Male             Single         Student
# 28    23  Female             Single        Employee
# 29    22    Male             Single         Student
# 30    22  Female             Single        Employee
# 31    22    Male             Single         Student
# 32    25    Male            Married        Employee
# 33    22  Female             Single         Student
# 34    22  Female             Single         Student
# 35    25    Male             Single         Student
# 36    25    Male             Single         Student
# 37    32  Female  Prefer not to say      House wife
# 38    23  Female             Single         Student
# 39    23  Female             Single         Student
# 40    30    Male            Married  Self Employeed
# 41    23    Male             Single         Student
# 42    23    Male             Single         Student
# 43    22  Female             Single         Student
# 44    22    Male             Single         Student
# 45    27  Female            Married  Self Employeed
# 46    24  Female             Single         Student
# 47    23    Male             Single         Student
# 48    23  Female             Single         Student
# 49    22  Female             Single         Student
# 50    23  Female             Single         Student
# 51    23  Female             Single         Student
# 52    24    Male             Single         Student
# 53    25    Male             Single         Student
# 54    22    Male             Single         Student
# 55    28  Female            Married         Student
# 56    22  Female             Single         Student
# 57    24  Female             Single         Student
# 58    31    Male            Married        Employee
# 59    25    Male             Single         Student
# 60    23    Male             Single         Student
# 61    22    Male             Single         Student
# 62    23    Male             Single         Student
# 63    23    Male             Single         Student
# 64    23  Female             Single         Student
# 65    25    Male             Single         Student
# 66    24    Male             Single        Employee
# 67    23  Female             Single         Student
# 68    23  Female             Single         Student
# 69    24  Female            Married        Employee
# 70    22    Male             Single         Student
# 71    24  Female             Single         Student
# 72    25  Female             Single         Student
# 73    23    Male             Single         Student
# 74    26    Male             Single         Student
# 75    24  Female             Single         Student
# 76    26    Male             Single         Student
# 77    21    Male             Single         Student
# 78    22  Female             Single         Student
# 79    24    Male             Single         Student
# 80    24    Male             Single         Student
# 81    23  Female             Single         Student
# 82    23    Male             Single         Student
# 83    22    Male             Single         Student
# 84    23    Male             Single         Student
# 85    24  Female             Single         Student
# 86    24    Male             Single         Student
# 87    25    Male             Single         Student
# 88    25    Male             Single         Student
# 89    28    Male            Married  Self Employeed
# 90    27  Female  Prefer not to say        Employee
# 91    26    Male             Single  Self Employeed
# 92    22    Male             Single         Student
# 93    24  Female             Single         Student
# 94    23    Male             Single         Student
# 95    25    Male             Single         Student
# 96    23  Female             Single         Student
# 97    23  Female             Single         Student
# 98    26    Male            Married        Employee
# 99    32  Female            Married      House wife
# 100   24  Female             Single         Student
# 101   23    Male             Single         Student
# 102   22  Female             Single        Employee
# 103   24  Female             Single         Student
# 104   26    Male             Single        Employee
# 105   28    Male            Married        Employee
# 106   26    Male             Single        Employee
# 107   25    Male             Single         Student
# 108   25    Male             Single        Employee
# 109   18    Male             Single         Student
# 110   21    Male             Single         Student
# 111   25    Male             Single         Student
# 112   25    Male             Single         Student
# 113   23  Female             Single         Student
# 114   23    Male             Single        Employee
# 115   25  Female            Married        Employee
# 116   31  Female            Married      House wife
# 117   24    Male  Prefer not to say  Self Employeed
# 118   32  Female            Married        Employee
# 119   25    Male             Single        Employee
# 120   27  Female            Married  Self Employeed
# 121   26    Male             Single  Self Employeed
# 122   26  Female             Single  Self Employeed
# 123   32    Male            Married        Employee
# 124   24    Male            Married  Self Employeed
# 125   27  Female            Married  Self Employeed
# 126   23    Male             Single         Student
# 127   25    Male             Single         Student
# 128   23    Male             Single         Student
# 129   23  Female             Single         Student
# 130   28    Male            Married        Employee
# 131   32  Female            Married        Employee
# 132   23    Male             Single         Student
# 133   19    Male             Single         Student
# 134   19  Female             Single         Student
# 135   27  Female            Married        Employee
# 136   25    Male             Single  Self Employeed
# 137   33    Male            Married        Employee
# 138   26  Female             Single        Employee
# 139   22  Female             Single         Student
# 140   23    Male             Single         Student
# 141   22  Female             Single         Student
# 142   25    Male            Married        Employee
# 143   30  Female            Married      House wife
# 144   24    Male             Single         Student
# 145   25    Male             Single        Employee
# 146   23    Male             Single         Student
# 147   24  Female             Single         Student
# 148   32    Male            Married        Employee
# 149   22    Male             Single         Student
# 150   23    Male             Single         Student
# 151   23  Female             Single         Student
# 152   20    Male             Single         Student
# 153   21    Male             Single         Student
# 154   24  Female            Married  Self Employeed
# 155   23  Female             Single         Student
# 156   25    Male             Single        Employee
# 157   32  Female            Married      House wife
# 158   27    Male            Married        Employee
# 159   20  Female             Single         Student
# 160   21    Male             Single         Student
# 161   26    Male             Single        Employee
# 162   25    Male             Single        Employee
# 163   26    Male             Single        Employee
# 164   26  Female            Married        Employee
# 165   27    Male             Single        Employee
# 166   27  Female             Single         Student
# 167   24  Female             Single         Student
# 168   25    Male            Married  Self Employeed
# 169   20    Male             Single         Student
# 170   22    Male             Single         Student
# 171   26  Female            Married         Student
# 172   27    Male  Prefer not to say        Employee
# 173   25  Female             Single         Student
# 174   24    Male             Single        Employee
# 175   23  Female             Single        Employee
# 176   22    Male             Single         Student
# 177   26    Male            Married  Self Employeed
# 178   26    Male             Single        Employee
# 179   25  Female            Married  Self Employeed
# 180   29  Female            Married        Employee
# 181   23    Male             Single         Student
# 182   22  Female             Single        Employee
# 183   22    Male             Single         Student
# 184   32  Female            Married      House wife
# 185   28    Male            Married        Employee
# 186   22    Male             Single         Student
# 187   25    Male             Single        Employee
# 188   26  Female            Married        Employee
# 189   31    Male            Married  Self Employeed
# 190   24    Male             Single         Student
# 191   24    Male             Single        Employee
# 192   31  Female            Married        Employee
# 193   26    Male             Single        Employee
# 194   24  Female            Married  Self Employeed
# 195   22  Female             Single         Student
# 196   19    Male             Single         Student
# 197   25    Male            Married        Employee
# 198   23  Female            Married      House wife
# 199   23  Female             Single         Student
# 200   23    Male             Single         Student
# 201   24    Male             Single         Student
# 202   22  Female             Single        Employee
# 203   26    Male            Married        Employee
# 204   25  Female             Single         Student
# 205   20    Male             Single         Student
# 206   29    Male            Married        Employee
# 207   23  Female             Single         Student
# 208   25    Male             Single  Self Employeed
# 209   29  Female            Married        Employee
# 210   27    Male            Married  Self Employeed
# 211   25    Male             Single  Self Employeed
# 212   21    Male             Single         Student
# 213   23    Male             Single         Student
# 214   24  Female             Single        Employee
# 215   32    Male            Married  Self Employeed
# 216   28    Male            Married        Employee
# 217   26    Male             Single        Employee
# 218   31  Female            Married      House wife
# 219   27  Female            Married  Self Employeed
# 220   21  Female             Single         Student
# 221   23  Female             Single         Student
# 222   26    Male            Married        Employee
# 223   32    Male            Married        Employee
# 224   25  Female            Married         Student
# 225   28    Male             Single  Self Employeed
# 226   21  Female             Single         Student
# 227   24    Male             Single         Student
# 228   26  Female            Married  Self Employeed
# 229   32    Male            Married        Employee
# 230   29    Male             Single  Self Employeed
# 231   21    Male             Single         Student
# 232   24  Female             Single  Self Employeed
# 233   26    Male  Prefer not to say  Self Employeed
# 234   25    Male            Married        Employee
# 235   29    Male             Single        Employee
# 236   22    Male             Single         Student
# 237   24    Male             Single         Student
# 238   27    Male            Married        Employee
# 239   23  Female             Single         Student
# 240   32    Male            Married        Employee
# 241   22  Female             Single         Student
# 242   28    Male            Married        Employee
# 243   23  Female             Single         Student
# 244   30    Male            Married  Self Employeed
# 245   21    Male             Single         Student
# 246   26  Female            Married        Employee
# 247   25    Male             Single  Self Employeed
# 248   31    Male  Prefer not to say        Employee
# 249   23  Female             Single        Employee
# 250   29  Female            Married        Employee
# 251   21    Male             Single         Student
# 252   20    Male             Single         Student
# 253   22    Male             Single        Employee
# 254   30  Female            Married      House wife
# 255   27    Male            Married  Self Employeed
# 256   23    Male             Single         Student
# 257   30    Male            Married  Self Employeed
# 258   23    Male             Single         Student
# 259   28  Female            Married        Employee
# 260   30    Male            Married  Self Employeed
# 261   24  Female            Married        Employee
# 262   21    Male             Single         Student
# 263   23  Female  Prefer not to say        Employee
# 264   25    Male            Married  Self Employeed
# 265   24  Female             Single        Employee
# 266   26    Male            Married        Employee
# 267   25  Female             Single        Employee
# 268   22    Male             Single         Student
# 269   26  Female             Single        Employee
# 270   23    Male             Single        Employee
# 271   21  Female             Single        Employee
# 272   25    Male            Married  Self Employeed
# 273   24  Female            Married        Employee
# 274   22    Male            Married         Student
# 275   23  Female             Single         Student
# 276   24    Male            Married        Employee
# 277   22  Female             Single         Student
# 278   30    Male            Married        Employee
# 279   23  Female  Prefer not to say        Employee
# 280   19    Male             Single         Student
# 281   21  Female             Single         Student
# 282   23    Male             Single         Student
# 283   24  Female             Single        Employee
# 284   26  Female            Married        Employee
# 285   26  Female             Single         Student
# 286   25  Female             Single         Student
# 287   28  Female            Married        Employee
# 288   25  Female             Single         Student
# 289   20  Female             Single         Student
# 290   27  Female            Married  Self Employeed
# 291   25  Female            Married        Employee
# 292   24  Female             Single         Student
# 293   25  Female            Married        Employee
# 294   25  Female  Prefer not to say        Employee
# 295   24  Female            Married         Student
# 296   24    Male             Single         Student
# 297   22    Male             Single        Employee
# 298   28    Male             Single        Employee
# 299   25  Female             Single        Employee
# 300   22    Male             Single         Student
# 301   22  Female             Single         Student
# 302   22    Male             Single         Student
# 303   27  Female            Married        Employee
# 304   22    Male             Single         Student
# 305   24  Female             Single         Student
# 306   23  Female             Single         Student
# 307   23  Female             Single         Student
# 308   22  Female             Single         Student
# 309   23    Male             Single         Student
# 310   32    Male            Married        Employee
# 311   25  Female            Married         Student
# 312   28    Male             Single  Self Employeed
# 313   21  Female             Single         Student
# 314   24    Male             Single         Student
# 315   26  Female            Married  Self Employeed
# 316   32    Male            Married        Employee
# 317   29    Male             Single  Self Employeed
# 318   21    Male             Single         Student
# 319   24  Female             Single  Self Employeed
# 320   26    Male  Prefer not to say  Self Employeed
# 321   21    Male            Married        Employee
# 322   29    Male             Single        Employee
# 323   22    Male             Single         Student
# 324   24    Male             Single         Student
# 325   27    Male            Married        Employee
# 326   23  Female             Single         Student
# 327   32    Male            Married        Employee
# 328   22  Female             Single         Student
# 329   22  Female             Single        Employee
# 330   26    Male            Married        Employee
# 331   25  Female             Single         Student
# 332   20    Male             Single         Student
# 333   29    Male            Married        Employee
# 334   23  Female             Single         Student
# 335   25    Male             Single  Self Employeed
# 336   29  Female            Married        Employee
# 337   27    Male            Married  Self Employeed
# 338   25    Male             Single  Self Employeed
# 339   21    Male             Single         Student
# 340   23    Male             Single         Student
# 341   24  Female             Single        Employee
# 342   22    Male            Married  Self Employeed
# 343   28    Male            Married        Employee
# 344   26    Male             Single        Employee
# 345   22  Female             Single        Employee
# 346   26    Male            Married        Employee
# 347   25  Female             Single         Student
# 348   20    Male             Single         Student
# 349   29    Male            Married        Employee
# 350   23  Female             Single         Student
# 351   25    Male             Single  Self Employeed
# 352   29  Female            Married        Employee
# 353   27    Male            Married  Self Employeed
# 354   25    Male             Single  Self Employeed
# 355   21    Male             Single         Student
# 356   24    Male             Single         Student
# 357   26  Female            Married  Self Employeed
# 358   32    Male            Married        Employee
# 359   29    Male             Single  Self Employeed
# 360   21    Male             Single         Student
# 361   24  Female             Single  Self Employeed
# 362   26    Male  Prefer not to say  Self Employeed
# 363   31    Male            Married        Employee
# 364   29    Male             Single        Employee
# 365   22    Male             Single         Student
# 366   24    Male             Single         Student
# 367   27    Male            Married        Employee
# 368   23  Female             Single         Student
# 369   30    Male            Married        Employee
# 370   22  Female             Single         Student
# 371   28    Male            Married        Employee
# 372   23  Female             Single         Student
# 373   30    Male            Married  Self Employeed
# 374   21    Male             Single         Student
# 375   26  Female            Married        Employee
# 376   25    Male             Single  Self Employeed
# 377   31    Male  Prefer not to say        Employee
# 378   23  Female             Single        Employee
# 379   22    Male             Single         Student
# 380   27  Female            Married        Employee
# 381   22    Male             Single         Student
# 382   24  Female             Single         Student
# 383   23  Female             Single         Student
# 384   23  Female             Single         Student
# 385   22  Female             Single         Student
# 386   23    Male             Single         Student
# 387   23    Male             Single         Student
#
#                   monthly_income educational_qualifications  family_size  \
# 0                      No Income              Post Graduate            4
# 1                Below 10000 INR                   Graduate            3
# 2                Below 10000 INR              Post Graduate            3
# 3                      No Income                   Graduate            6
# 4                Below 10000 INR              Post Graduate            4
# 5            More than 50000 INR              Post Graduate            2
# 6                      No Income                   Graduate            3
# 7                      No Income              Post Graduate            3
# 8                      No Income              Post Graduate            2
# 9                      No Income              Post Graduate            4
# 10                     No Income              Post Graduate            5
# 11               Below 10000 INR              Post Graduate            2
# 12                     No Income              Post Graduate            5
# 13                     No Income                   Graduate            4
# 14   Between 10001 and 25000 INR              Post Graduate            5
# 15                     No Income              Post Graduate            6
# 16   Between 25001 and 50000 INR              Post Graduate            2
# 17                     No Income                   Graduate            3
# 18                     No Income                   Graduate            4
# 19               Below 10000 INR              Post Graduate            1
# 20                     No Income              Post Graduate            3
# 21                     No Income              Post Graduate            4
# 22                     No Income                   Graduate            4
# 23                     No Income                   Graduate            4
# 24               Below 10000 INR              Post Graduate            3
# 25                     No Income              Post Graduate            3
# 26                     No Income              Post Graduate            5
# 27                     No Income              Post Graduate            3
# 28   Between 10001 and 25000 INR                   Graduate            3
# 29               Below 10000 INR              Post Graduate            4
# 30   Between 10001 and 25000 INR                   Graduate            5
# 31                     No Income              Post Graduate            4
# 32           More than 50000 INR                       Ph.D            4
# 33   Between 10001 and 25000 INR              Post Graduate            5
# 34                     No Income              Post Graduate            2
# 35   Between 10001 and 25000 INR              Post Graduate            3
# 36                     No Income              Post Graduate            5
# 37                     No Income                   Graduate            5
# 38                     No Income              Post Graduate            3
# 39                     No Income              Post Graduate            4
# 40           More than 50000 INR                 Uneducated            4
# 41                     No Income                   Graduate            3
# 42                     No Income              Post Graduate            4
# 43                     No Income              Post Graduate            5
# 44                     No Income                   Graduate            5
# 45   Between 10001 and 25000 INR              Post Graduate            2
# 46                     No Income              Post Graduate            3
# 47                     No Income              Post Graduate            2
# 48                     No Income                   Graduate            3
# 49   Between 10001 and 25000 INR              Post Graduate            5
# 50                     No Income                   Graduate            5
# 51                     No Income              Post Graduate            2
# 52                     No Income              Post Graduate            3
# 53                     No Income              Post Graduate            2
# 54                     No Income              Post Graduate            3
# 55                     No Income                   Graduate            2
# 56                     No Income              Post Graduate            1
# 57                     No Income                   Graduate            3
# 58           More than 50000 INR                       Ph.D            5
# 59                     No Income              Post Graduate            4
# 60                     No Income              Post Graduate            5
# 61                     No Income              Post Graduate            3
# 62   Between 25001 and 50000 INR              Post Graduate            1
# 63                     No Income                   Graduate            4
# 64                     No Income              Post Graduate            2
# 65                     No Income              Post Graduate            6
# 66   Between 10001 and 25000 INR                   Graduate            4
# 67                     No Income              Post Graduate            4
# 68                     No Income              Post Graduate            4
# 69           More than 50000 INR                       Ph.D            4
# 70                     No Income                   Graduate            4
# 71   Between 10001 and 25000 INR              Post Graduate            3
# 72                     No Income              Post Graduate            3
# 73                     No Income              Post Graduate            2
# 74                     No Income              Post Graduate            4
# 75   Between 25001 and 50000 INR              Post Graduate            3
# 76                     No Income              Post Graduate            4
# 77                     No Income                   Graduate            4
# 78                     No Income              Post Graduate            3
# 79                     No Income              Post Graduate            5
# 80   Between 10001 and 25000 INR              Post Graduate            4
# 81                     No Income              Post Graduate            3
# 82                     No Income              Post Graduate            3
# 83                     No Income              Post Graduate            3
# 84                     No Income              Post Graduate            3
# 85                     No Income              Post Graduate            4
# 86                     No Income              Post Graduate            5
# 87                     No Income                   Graduate            1
# 88                     No Income              Post Graduate            5
# 89   Between 10001 and 25000 INR                   Graduate            2
# 90   Between 25001 and 50000 INR              Post Graduate            5
# 91   Between 10001 and 25000 INR                       Ph.D            1
# 92                     No Income              Post Graduate            2
# 93                     No Income              Post Graduate            3
# 94                     No Income              Post Graduate            1
# 95                     No Income                   Graduate            1
# 96                     No Income                   Graduate            5
# 97                     No Income                   Graduate            5
# 98   Between 25001 and 50000 INR                   Graduate            5
# 99                     No Income                 Uneducated            3
# 100  Between 10001 and 25000 INR              Post Graduate            3
# 101                    No Income              Post Graduate            2
# 102  Between 10001 and 25000 INR                   Graduate            3
# 103                    No Income                       Ph.D            3
# 104  Between 25001 and 50000 INR                   Graduate            2
# 105          More than 50000 INR                   Graduate            3
# 106          More than 50000 INR              Post Graduate            2
# 107                    No Income              Post Graduate            1
# 108              Below 10000 INR                   Graduate            2
# 109                    No Income                   Graduate            5
# 110                    No Income              Post Graduate            4
# 111                    No Income              Post Graduate            1
# 112              Below 10000 INR              Post Graduate            2
# 113                    No Income                   Graduate            5
# 114  Between 10001 and 25000 INR              Post Graduate            2
# 115  Between 25001 and 50000 INR                   Graduate            4
# 116                    No Income                     School            5
# 117          More than 50000 INR                       Ph.D            2
# 118  Between 25001 and 50000 INR                   Graduate            5
# 119  Between 25001 and 50000 INR                   Graduate            3
# 120          More than 50000 INR                   Graduate            5
# 121  Between 25001 and 50000 INR                   Graduate            3
# 122  Between 25001 and 50000 INR              Post Graduate            3
# 123          More than 50000 INR                       Ph.D            5
# 124          More than 50000 INR                       Ph.D            6
# 125  Between 25001 and 50000 INR                   Graduate            3
# 126                    No Income              Post Graduate            3
# 127                    No Income              Post Graduate            4
# 128                    No Income              Post Graduate            3
# 129                    No Income              Post Graduate            4
# 130          More than 50000 INR              Post Graduate            3
# 131          More than 50000 INR                   Graduate            1
# 132                    No Income              Post Graduate            2
# 133                    No Income                   Graduate            2
# 134                    No Income                   Graduate            4
# 135  Between 25001 and 50000 INR              Post Graduate            2
# 136  Between 25001 and 50000 INR                   Graduate            3
# 137          More than 50000 INR                       Ph.D            5
# 138          More than 50000 INR                   Graduate            3
# 139              Below 10000 INR              Post Graduate            4
# 140                    No Income              Post Graduate            3
# 141                    No Income                   Graduate            3
# 142  Between 25001 and 50000 INR                   Graduate            2
# 143                    No Income                     School            5
# 144                    No Income              Post Graduate            3
# 145  Between 10001 and 25000 INR              Post Graduate            3
# 146          More than 50000 INR              Post Graduate            3
# 147                    No Income              Post Graduate            4
# 148  Between 10001 and 25000 INR                   Graduate            4
# 149                    No Income              Post Graduate            4
# 150          More than 50000 INR              Post Graduate            3
# 151                    No Income              Post Graduate            4
# 152                    No Income                   Graduate            2
# 153                    No Income                   Graduate            2
# 154  Between 10001 and 25000 INR                   Graduate            5
# 155                    No Income              Post Graduate            4
# 156  Between 25001 and 50000 INR              Post Graduate            3
# 157                    No Income                   Graduate            3
# 158          More than 50000 INR                       Ph.D            5
# 159                    No Income                   Graduate            2
# 160                    No Income                   Graduate            2
# 161          More than 50000 INR              Post Graduate            3
# 162  Between 10001 and 25000 INR                   Graduate            4
# 163  Between 25001 and 50000 INR              Post Graduate            3
# 164  Between 25001 and 50000 INR                   Graduate            3
# 165          More than 50000 INR                       Ph.D            4
# 166                    No Income                       Ph.D            5
# 167                    No Income              Post Graduate            5
# 168          More than 50000 INR                     School            2
# 169                    No Income                   Graduate            2
# 170                    No Income              Post Graduate            1
# 171              Below 10000 INR                       Ph.D            3
# 172  Between 25001 and 50000 INR              Post Graduate            1
# 173                    No Income              Post Graduate            3
# 174              Below 10000 INR                   Graduate            2
# 175  Between 10001 and 25000 INR                   Graduate            6
# 176                    No Income                   Graduate            2
# 177          More than 50000 INR              Post Graduate            3
# 178              Below 10000 INR              Post Graduate            1
# 179  Between 25001 and 50000 INR              Post Graduate            3
# 180          More than 50000 INR                   Graduate            3
# 181              Below 10000 INR                   Graduate            3
# 182  Between 25001 and 50000 INR                   Graduate            4
# 183                    No Income                   Graduate            2
# 184                    No Income                     School            5
# 185          More than 50000 INR              Post Graduate            1
# 186                    No Income              Post Graduate            2
# 187  Between 10001 and 25000 INR                   Graduate            2
# 188  Between 25001 and 50000 INR              Post Graduate            2
# 189          More than 50000 INR                     School            6
# 190                    No Income              Post Graduate            3
# 191  Between 25001 and 50000 INR              Post Graduate            2
# 192          More than 50000 INR                       Ph.D            5
# 193  Between 25001 and 50000 INR                   Graduate            2
# 194          More than 50000 INR                   Graduate            2
# 195                    No Income                   Graduate            3
# 196                    No Income                   Graduate            6
# 197          More than 50000 INR              Post Graduate            6
# 198                    No Income                     School            6
# 199                    No Income                   Graduate            2
# 200                    No Income              Post Graduate            2
# 201                    No Income              Post Graduate            5
# 202  Between 25001 and 50000 INR                   Graduate            4
# 203          More than 50000 INR                   Graduate            4
# 204                    No Income                       Ph.D            3
# 205                    No Income                   Graduate            2
# 206  Between 25001 and 50000 INR                   Graduate            4
# 207                    No Income                   Graduate            1
# 208          More than 50000 INR                   Graduate            2
# 209  Between 25001 and 50000 INR                   Graduate            4
# 210  Between 25001 and 50000 INR                   Graduate            6
# 211  Between 10001 and 25000 INR                   Graduate            3
# 212                    No Income                   Graduate            2
# 213                    No Income                   Graduate            3
# 214  Between 10001 and 25000 INR              Post Graduate            4
# 215  Between 10001 and 25000 INR                     School            3
# 216  Between 25001 and 50000 INR              Post Graduate            5
# 217  Between 10001 and 25000 INR                   Graduate            2
# 218                    No Income                   Graduate            5
# 219  Between 25001 and 50000 INR                   Graduate            3
# 220                    No Income              Post Graduate            1
# 221                    No Income                   Graduate            2
# 222  Between 10001 and 25000 INR                   Graduate            4
# 223          More than 50000 INR                   Graduate            5
# 224                    No Income              Post Graduate            2
# 225  Between 10001 and 25000 INR              Post Graduate            2
# 226                    No Income              Post Graduate            3
# 227                    No Income              Post Graduate            2
# 228  Between 10001 and 25000 INR                   Graduate            5
# 229  Between 25001 and 50000 INR                   Graduate            3
# 230          More than 50000 INR                   Graduate            6
# 231                    No Income                   Graduate            5
# 232  Between 25001 and 50000 INR              Post Graduate            3
# 233          More than 50000 INR              Post Graduate            2
# 234          More than 50000 INR                       Ph.D            3
# 235  Between 25001 and 50000 INR                   Graduate            3
# 236                    No Income                   Graduate            3
# 237                    No Income                   Graduate            2
# 238  Between 25001 and 50000 INR                   Graduate            2
# 239                    No Income              Post Graduate            3
# 240          More than 50000 INR              Post Graduate            6
# 241                    No Income                   Graduate            2
# 242  Between 25001 and 50000 INR                   Graduate            3
# 243                    No Income              Post Graduate            2
# 244          More than 50000 INR                   Graduate            1
# 245                    No Income                   Graduate            3
# 246              Below 10000 INR                   Graduate            6
# 247          More than 50000 INR                     School            3
# 248              Below 10000 INR                   Graduate            1
# 249  Between 25001 and 50000 INR              Post Graduate            2
# 250  Between 25001 and 50000 INR                       Ph.D            3
# 251                    No Income                   Graduate            6
# 252                    No Income                   Graduate            3
# 253  Between 10001 and 25000 INR                   Graduate            2
# 254                    No Income                     School            6
# 255          More than 50000 INR                   Graduate            3
# 256                    No Income              Post Graduate            2
# 257  Between 25001 and 50000 INR                     School            6
# 258                    No Income              Post Graduate            3
# 259  Between 25001 and 50000 INR              Post Graduate            6
# 260          More than 50000 INR                   Graduate            6
# 261  Between 25001 and 50000 INR              Post Graduate            2
# 262                    No Income                   Graduate            2
# 263  Between 10001 and 25000 INR                   Graduate            3
# 264          More than 50000 INR              Post Graduate            4
# 265  Between 25001 and 50000 INR                   Graduate            2
# 266  Between 10001 and 25000 INR                   Graduate            3
# 267  Between 25001 and 50000 INR              Post Graduate            2
# 268  Between 25001 and 50000 INR                   Graduate            3
# 269  Between 25001 and 50000 INR              Post Graduate            2
# 270  Between 10001 and 25000 INR                   Graduate            2
# 271              Below 10000 INR                   Graduate            2
# 272  Between 25001 and 50000 INR                   Graduate            3
# 273  Between 10001 and 25000 INR              Post Graduate            2
# 274                    No Income                   Graduate            2
# 275                    No Income              Post Graduate            4
# 276          More than 50000 INR              Post Graduate            3
# 277                    No Income                   Graduate            2
# 278          More than 50000 INR                   Graduate            5
# 279  Between 10001 and 25000 INR                   Graduate            4
# 280                    No Income                   Graduate            6
# 281                    No Income                   Graduate            2
# 282                    No Income                   Graduate            4
# 283  Between 25001 and 50000 INR                   Graduate            3
# 284  Between 10001 and 25000 INR              Post Graduate            2
# 285                    No Income                       Ph.D            2
# 286  Between 10001 and 25000 INR                   Graduate            2
# 287  Between 25001 and 50000 INR                   Graduate            5
# 288                    No Income              Post Graduate            3
# 289                    No Income                   Graduate            2
# 290          More than 50000 INR                   Graduate            6
# 291  Between 25001 and 50000 INR                   Graduate            3
# 292                    No Income              Post Graduate            5
# 293          More than 50000 INR                   Graduate            1
# 294  Between 25001 and 50000 INR              Post Graduate            3
# 295              Below 10000 INR                       Ph.D            5
# 296                    No Income              Post Graduate            3
# 297  Between 10001 and 25000 INR                   Graduate            1
# 298  Between 25001 and 50000 INR              Post Graduate            2
# 299          More than 50000 INR              Post Graduate            6
# 300              Below 10000 INR              Post Graduate            3
# 301                    No Income                   Graduate            6
# 302              Below 10000 INR              Post Graduate            4
# 303          More than 50000 INR              Post Graduate            2
# 304                    No Income                   Graduate            3
# 305                    No Income              Post Graduate            3
# 306                    No Income              Post Graduate            2
# 307                    No Income              Post Graduate            4
# 308                    No Income              Post Graduate            5
# 309              Below 10000 INR              Post Graduate            2
# 310          More than 50000 INR                   Graduate            5
# 311                    No Income              Post Graduate            2
# 312  Between 10001 and 25000 INR              Post Graduate            2
# 313                    No Income              Post Graduate            3
# 314                    No Income              Post Graduate            2
# 315  Between 10001 and 25000 INR                   Graduate            5
# 316  Between 25001 and 50000 INR                   Graduate            3
# 317          More than 50000 INR                   Graduate            6
# 318                    No Income                   Graduate            5
# 319  Between 25001 and 50000 INR              Post Graduate            3
# 320          More than 50000 INR              Post Graduate            2
# 321          More than 50000 INR                       Ph.D            3
# 322  Between 25001 and 50000 INR                   Graduate            3
# 323                    No Income                   Graduate            3
# 324                    No Income                   Graduate            2
# 325  Between 25001 and 50000 INR                   Graduate            2
# 326                    No Income              Post Graduate            3
# 327          More than 50000 INR              Post Graduate            6
# 328                    No Income                   Graduate            2
# 329  Between 25001 and 50000 INR                   Graduate            4
# 330          More than 50000 INR                   Graduate            4
# 331                    No Income                       Ph.D            3
# 332                    No Income                   Graduate            2
# 333  Between 25001 and 50000 INR                   Graduate            4
# 334                    No Income                   Graduate            1
# 335          More than 50000 INR                   Graduate            2
# 336  Between 25001 and 50000 INR                   Graduate            4
# 337  Between 25001 and 50000 INR                   Graduate            6
# 338  Between 10001 and 25000 INR                   Graduate            3
# 339                    No Income                   Graduate            2
# 340                    No Income                   Graduate            3
# 341  Between 10001 and 25000 INR              Post Graduate            4
# 342  Between 10001 and 25000 INR                     School            3
# 343  Between 25001 and 50000 INR              Post Graduate            5
# 344  Between 10001 and 25000 INR                   Graduate            2
# 364   13.0641    77.5931    560092   False  Negative
# 365   13.0158    77.5390    560096    True   Positive
# 366   12.9561    77.5921    560027    True   Positive
# 367   12.8845    77.6036    560076    True   Positive
# 368   12.9369    77.6407    560095   False   Positive
# 369   12.9369    77.6407    560095    True   Positive
# 370   12.9369    77.6407    560095    True   Positive
# 371   12.9369    77.6407    560095    True   Positive
# 372   13.0158    77.5390    560096    True   Positive
# 373   13.0809    77.5565    560097   False  Negative
# 374   13.0641    77.5931    560092    True  Negative
# 375   12.9859    77.6713    560093   False  Negative
# 376   12.9859    77.6713    560093    True   Positive
# 377   12.9866    77.4904    560091   False  Negative
# 378   12.9847    77.5491    560100    True   Positive
# 379   12.9850    77.5533    560010    True   Positive
# 380   12.9299    77.6848    560103    True   Positive
# 381   12.9770    77.5773    560009    True   Positive
# 382   12.9828    77.6131    560042    True   Positive
# 383   12.9766    77.5993    560001    True   Positive
# 384   12.9854    77.7081    560048    True   Positive
# 385   12.9850    77.5533    560010    True   Positive
# 386   12.9770    77.5773    560009    True   Positive
# 387   12.8988    77.5764    560078    True   Positive

# %%
df_onlinefoods.head()
# Out:
#    age  gender marital_status occupation   monthly_income  \
# 0   20  Female         Single    Student        No Income
# 1   24  Female         Single    Student  Below 10000 INR
# 2   22    Male         Single    Student  Below 10000 INR
# 3   22  Female         Single    Student        No Income
# 4   22    Male         Single    Student  Below 10000 INR
#
#   educational_qualifications  family_size  latitude  longitude  pin_code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#    output   feedback
# 0    True   Positive
# 1    True   Positive
# 2    True  Negative
# 3    True   Positive
# 4    True   Positive

# %%
df_onlinefoods.tail()
# Out:
#      age  gender marital_status occupation   monthly_income  \
# 383   23  Female         Single    Student        No Income
# 384   23  Female         Single    Student        No Income
# 385   22  Female         Single    Student        No Income
# 386   23    Male         Single    Student  Below 10000 INR
# 387   23    Male         Single    Student        No Income
#
#     educational_qualifications  family_size  latitude  longitude  pin_code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#      output  feedback
# 383    True  Positive
# 384    True  Positive
# 385    True  Positive
# 386    True  Positive
# 387    True  Positive

# %%
df_onlinefoods.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'occupation', 'monthly_income',
#        'educational_qualifications', 'family_size', 'latitude', 'longitude',
#        'pin_code', 'output', 'feedback'],
#       dtype='object')

# %%
print(df_onlinefoods.dtypes)
# Out:
# age                             int64
# gender                         object
# marital_status                 object
# occupation                     object
# monthly_income                 object
# educational_qualifications     object
# family_size                     int64
# latitude                      float64
# longitude                     float64
# pin_code                        int64
# output                           bool
# feedback                       object
# dtype: object

# %% [markdown]
# ### <center>**CSV DOCUMENT SAVING📁**</center>

# %%
# Saving the dataset to a csv file without an index.
df_onlinefoods.to_csv("onlinefoods_eda_completed.csv",index=False) # index=False prevents saving the row indices in the file
