# %% [markdown]
# ### <center>**VISUALISATION IN PYTHON💹**</center>
#
# _____

# %%
# Managing Data.
import pandas as pd
import numpy as np
import re
# -----------------------------------------------------------------------

# Evaluating the distribution of the relationship between variables.
import scipy.stats as stats
from scipy.stats import ttest_ind, norm, chi2_contingency, f_oneway
from scipy.stats import shapiro, kstest, poisson, chisquare, expon

# -----------------------------------------------------------------------

# Imputing nulls using advanced statistical methods.
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.linear_model import LinearRegression

# -----------------------------------------------------------------------

# Visualisation libraries.
import seaborn as sns
import matplotlib.pyplot as plt

# -----------------------------------------------------------------------

# Managing warnings.
import warnings
warnings.filterwarnings("ignore")

# -----------------------------------------------------------------------

# Configuration: Checking the setting of the display to its maximum capacity to better show the dataframe.
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# Opening/Reading the csv document as a DataFrame to start the process of exploration and analysis of the data.
df_onlinefoods = pd.read_csv("onlinefoods_eda_completed.csv")

# %%
df_onlinefoods.head(3)
# Out:
#    age  gender marital_status occupation   monthly_income  \
# 0   20  Female         Single    Student        No Income
# 1   24  Female         Single    Student  Below 10000 INR
# 2   22    Male         Single    Student  Below 10000 INR
#
#   educational_qualifications  family_size  latitude  longitude  pin_code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
#
#    output   feedback
# 0    True   Positive
# 1    True   Positive
# 2    True  Negative

# %% [markdown]
# #### For the following graphs we will be using the color palette called inferno. Here are the range of colours included:

# %%
# Create a gradient from 0 to 1 with 256 points, reshaped to a 1-row array
gradient = np.linspace(0, 1, 256).reshape(1, -1)


# Create a figure to display the gradient
plt.figure(figsize=(8, 2))  # Set the figure size to 8x2 inches
plt.imshow(gradient, aspect='auto', cmap='inferno')  # Display the gradient using the "inferno" colormap
plt.axis('off')  # Turn off the axes for a clean visualization
plt.title("Inferno Color Palette", color='white')  # Add a title with white text color
plt.show()  # Display the plot

# %% [markdown]
# #### **<span>NUMERICAL DATA ANALYSIS**</span>
#
# _______
#
# #### **<span style="color:#e84d8b">Histplot</span> 📈**
# #### **<span style="color:#e84d8b">Scatterplot</span> 🌌**
# #### **<span style="color:#e84d8b">Regplot</span> 📉**
# #### **<span style="color:#e84d8b">Lineplot<span> 📈**
# #### **<span style="color:#e84d8b">Heatmap</span> 🌡️**

# %% [markdown]
# **NUMERICAL COLUMNS:**
#
# ['age'], ['family_size'], ['latitude'], ['longitude'] and ['pin_code']

# %%
# We configurate the font and palette, using the "inferno palette"
sns.set_palette("inferno")


# Create the figure and axis
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Using 'sns.hisplot()' , we create the chart with Seaborn.
sns.histplot(x = "age", 
             data = df_onlinefoods, 
             edgecolor = 'fuchsia',
             color = "violet",
             ax = ax,
             kde = True, 
             bins = 20 )


# Using 'ax.set_xlabel/ylabel()', we name the axis and edit the colour and size of the labels.
ax.set_xlabel("Age", fontsize=16, color='white')  # Changes the name, colour and font size of axis X
ax.set_ylabel("Count", fontsize=16, color='white') # Changes the name, colour and font size of axis Y


# Using 'ax.spines[]', we edit the axis.
ax.spines['top'].set_visible(False)     # Hides the top line
ax.spines['right'].set_visible(False)   # Hides the right line
ax.spines['left'].set_linewidth(2.5)    # Makes the Y axis line thicker
ax.spines['bottom'].set_linewidth(2.5)  # Makes the X axis line thicker
ax.spines['left'].set_color('yellow')   # Changes the colour of the Y axis
ax.spines['bottom'].set_color('yellow') # Changes the colour of the X axis


# Using 'ax.tick_params()', we edit the colour of the numbers on the axis.
ax.tick_params(axis='x', colors='yellow')  # Edits the colour of the numbers of the X axis
ax.tick_params(axis='y', colors='yellow')  # Edits the colour of the numbers of the Y axis


# Using 'plt.title()', we name the chart.
plt.title("Distribution of Age in dataset.", fontsize=14, color='white', pad=30);

# %%
# We configurate the font and palette, using the "inferno palette"
sns.set_palette("inferno")


# Create the figure and axis
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Using 'sns.hisplot()', we create the chart with Seaborn.
sns.histplot(x = "family_size", 
             data = df_onlinefoods, 
             edgecolor = 'fuchsia',
             color = "violet",
             ax = ax,
             kde = True, 
             bins = 20 )


# Using 'ax.set_xlabel/ylabel()', we name the axis and edit the colour and size of the labels.
ax.set_xlabel("Family Size", fontsize=16, color='white')  # Changes the name, colour and font size of axis X
ax.set_ylabel("Count", fontsize=16, color='white') # Changes the name, colour and font size of axis Y


# Using 'ax.spines[]', we edit the axis.
ax.spines['top'].set_visible(False)     # Hides the top line
ax.spines['right'].set_visible(False)   # Hides the right line
ax.spines['left'].set_linewidth(2.5)    # Makes the Y axis line thicker
ax.spines['bottom'].set_linewidth(2.5)  # Makes the X axis line thicker
ax.spines['left'].set_color('yellow')   # Changes the colour of the Y axis
ax.spines['bottom'].set_color('yellow') # Changes the colour of the X axis


# Using 'ax.tick_params()', we edit the colour of the numbers on the axis.
ax.tick_params(axis='x', colors='yellow')  # Edits the colour of the numbers of the X axis
ax.tick_params(axis='y', colors='yellow')  # Edits the colour of the numbers of the Y axis


# Using 'plt.title()', we name the chart.
plt.title("Distribution of Family Size in dataset.", fontsize=14, color='white', pad=30);

# %%
# We configurate the font and palette, using the "inferno palette"
sns.set_palette("inferno")


# Create the figure and axis
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Using 'sns.hisplot()', we create the chart with Seaborn.
sns.histplot(x = "latitude", 
             data = df_onlinefoods, 
             edgecolor = 'fuchsia',
             ax = ax,
             color = "purple", 
             kde = True, 
             bins = 20 )


# Using 'ax.set_xlabel/ylabel()', we name the axis and edit the colour and size of the labels.
ax.set_xlabel("Latitude", fontsize=16, color='white')  # Changes the name, colour and font size of axis X
ax.set_ylabel("Count", fontsize=16, color='white') # Changes the name, colour and font size of axis Y


# Using 'ax.spines[]', we edit the axis.
ax.spines['top'].set_visible(False)     # Hides the top line
ax.spines['right'].set_visible(False)   # Hides the right line
ax.spines['left'].set_linewidth(2.5)    # Makes the Y axis line thicker
ax.spines['bottom'].set_linewidth(2.5)  # Makes the X axis line thicker
ax.spines['left'].set_color('yellow')   # Changes the colour of the Y axis
ax.spines['bottom'].set_color('yellow') # Changes the colour of the X axis


# Using 'ax.tick_params()', we edit the colour of the numbers on the axis.
ax.tick_params(axis='x', colors='yellow')  # Edits the colour of the numbers of the X axis
ax.tick_params(axis='y', colors='yellow')  # Edits the colour of the numbers of the Y axis


# Using 'plt.title()', we name the chart.
plt.title("Distribution of latitude in dataset.", fontsize=14, color='white', pad=30);

# %%
# We configurate the font and palette, using the "inferno palette"
sns.set_palette("inferno")


# Create the figure and axis
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Using 'sns.hisplot()', we create the chart with Seaborn.
sns.histplot(x = "longitude", 
             data = df_onlinefoods, 
             edgecolor = 'fuchsia',
             ax = ax,
             color = "purple", 
             kde = True, 
             bins = 20 )


# Using 'ax.set_xlabel/ylabel()', we name the axis and edit the colour and size of the labels.
ax.set_xlabel("Longitude", fontsize=16, color='white')  # Changes the name, colour and font size of axis X
ax.set_ylabel("Count", fontsize=16, color='white') # Changes the name, colour and font size of axis Y


# Using 'ax.spines[]', we edit the axis.
ax.spines['top'].set_visible(False)     # Hides the top line
ax.spines['right'].set_visible(False)   # Hides the right line
ax.spines['left'].set_linewidth(2.5)    # Makes the Y axis line thicker
ax.spines['bottom'].set_linewidth(2.5)  # Makes the X axis line thicker
ax.spines['left'].set_color('yellow')   # Changes the colour of the Y axis
ax.spines['bottom'].set_color('yellow') # Changes the colour of the X axis


# Using 'ax.tick_params()', we edit the colour of the numbers on the axis.
ax.tick_params(axis='x', colors='yellow')  # Edits the colour of the numbers of the X axis
ax.tick_params(axis='y', colors='yellow')  # Edits the colour of the numbers of the Y axis


# Using 'plt.title()', we name the chart.
plt.title("Distribution of longitude in dataset.", fontsize=14, color='white', pad=30);

# %% [markdown]
# #### **<span>CATEGORICAL DATA ANALYSIS**</span>
#
# ______
#
# #### **<span style="color:#01bef4">Countplot</span> 🔢**
# #### **<span style="color:#01bef4">Pieplot</span> 🥧**

# %% [markdown]
# #### **<span>BOTH NUMERICAL & CATEGORICAL**</span>
#
# ______
#
# #### **<span style="color:#00bf63">Violinplot</span> 🎻**
# #### **<span style="color:#00bf63">Boxplot</span> 📦**
# #### **<span style="color:#00bf63">Barplot</span> 📊**

# %% [markdown]
# **CATEGORICAL COLUMNS:**
#
# ['gender'], ['marital_status'], ['occupation'], ['monthly_income'], ['educational_qualifications'], and ['feedback']

# %% [markdown]
# #### **<span style="color:#01bef4">Countplot</span> 🔢 - Useful for identifying the frequency of occurrences and comparing the distribution of categories within the Dataset.**

# %%
# Create the countplot with a specific color palette
sns.set_palette("inferno")  


# Create the figure and axis to have more control over the plot's layout and properties
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Create the countplot on the given axis
sns.countplot(x = "gender", 
              data = df_onlinefoods,
              edgecolor = 'yellow',
              color = '#f9e68b',
              ax = ax)


# Customize the axis appearance
ax.tick_params(colors='fuchsia')       # Set the tick colors to white for visibility

ax.spines['top'].set_linewidth(2)    # Increase the top axis thickness
ax.spines['right'].set_linewidth(2)  # Increase the right axis thickness
ax.spines['left'].set_linewidth(2)   # Increase the left axis thickness
ax.spines['bottom'].set_linewidth(2) # Increase the bottom axis thickness
ax.spines['left'].set_color('fuchsia')  # Set the color of the spines to white
ax.spines['bottom'].set_color('fuchsia')  # Set the color of the spines to white

# Customize axis labels
ax.set_xlabel("Gender", fontsize=12, color='white')  # Set x-axis label color and size
ax.set_ylabel("Count", fontsize=12, color='white')   # Set y-axis label color and size


# Rotate x-axis labels for better readability
plt.xticks(rotation=90, color="white")  # Make x-tick labels white


# Show the plot
plt.show();

# %%
# Create the countplot with a specific color palette
sns.set_palette("inferno")  


# Create the figure and axis to have more control over the plot's layout and properties
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Create the countplot on the given axis
sns.countplot(x = "marital_status", 
              data = df_onlinefoods,
              edgecolor = 'yellow',
              color = '#f9e68b',
              ax = ax)


# Customize the axis appearance
ax.tick_params(colors='fuchsia')       # Set the tick colors to white for visibility

ax.spines['top'].set_linewidth(2)    # Increase the top axis thickness
ax.spines['right'].set_linewidth(2)  # Increase the right axis thickness
ax.spines['left'].set_linewidth(2)   # Increase the left axis thickness
ax.spines['bottom'].set_linewidth(2) # Increase the bottom axis thickness
ax.spines['left'].set_color('fuchsia')  # Set the color of the spines to white
ax.spines['bottom'].set_color('fuchsia')  # Set the color of the spines to white

# Customize axis labels
ax.set_xlabel("Marital Status", fontsize=12, color='white')  # Set x-axis label color and size
ax.set_ylabel("Count", fontsize=12, color='white')   # Set y-axis label color and size


# Rotate x-axis labels for better readability
plt.xticks(rotation=90, color="white")  # Make x-tick labels white


# Show the plot
plt.show();

# %%
# Create the countplot with a specific color palette
sns.set_palette("inferno")  


# Create the figure and axis to have more control over the plot's layout and properties
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Create the countplot on the given axis
sns.countplot(x = "occupation", 
              data = df_onlinefoods,
              edgecolor = 'yellow',
              color = '#f9e68b',
              ax = ax)


# Customize the axis appearance
ax.tick_params(colors='fuchsia')       # Set the tick colors to white for visibility

ax.spines['top'].set_linewidth(2)    # Increase the top axis thickness
ax.spines['right'].set_linewidth(2)  # Increase the right axis thickness
ax.spines['left'].set_linewidth(2)   # Increase the left axis thickness
ax.spines['bottom'].set_linewidth(2) # Increase the bottom axis thickness
ax.spines['left'].set_color('fuchsia')  # Set the color of the spines to white
ax.spines['bottom'].set_color('fuchsia')  # Set the color of the spines to white

# Customize axis labels
ax.set_xlabel("Occupation", fontsize=12, color='white')  # Set x-axis label color and size
ax.set_ylabel("Count", fontsize=12, color='white')   # Set y-axis label color and size


# Rotate x-axis labels for better readability
plt.xticks(rotation=90, color="white")  # Make x-tick labels white


# Show the plot
plt.show();

# %%
# Create the countplot with a specific color palette
sns.set_palette("inferno")  


# Create the figure and axis to have more control over the plot's layout and properties
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Create the countplot on the given axis
sns.countplot(x = "monthly_income", 
              data = df_onlinefoods,
              edgecolor = 'yellow',
              color = '#f9e68b',
              ax = ax)


# Customize the axis appearance
ax.tick_params(colors='fuchsia')       # Set the tick colors to white for visibility

ax.spines['top'].set_linewidth(2)    # Increase the top axis thickness
ax.spines['right'].set_linewidth(2)  # Increase the right axis thickness
ax.spines['left'].set_linewidth(2)   # Increase the left axis thickness
ax.spines['bottom'].set_linewidth(2) # Increase the bottom axis thickness
ax.spines['left'].set_color('fuchsia')  # Set the color of the spines to white
ax.spines['bottom'].set_color('fuchsia')  # Set the color of the spines to white

# Customize axis labels
ax.set_xlabel("Monthly Income", fontsize=12, color='white')  # Set x-axis label color and size
ax.set_ylabel("Count", fontsize=12, color='white')   # Set y-axis label color and size


# Rotate x-axis labels for better readability
plt.xticks(rotation=90, color="white")  # Make x-tick labels white


# Show the plot
plt.show();

# %%
# Create the countplot with a specific color palette
sns.set_palette("inferno")  


# Create the figure and axis to have more control over the plot's layout and properties
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Create the countplot on the given axis
sns.countplot(x = "educational_qualifications", 
              data = df_onlinefoods,
              edgecolor = 'yellow',
              color = '#f9e68b',
              ax = ax)


# Customize the axis appearance
ax.tick_params(colors='fuchsia')       # Set the tick colors to white for visibility

ax.spines['top'].set_linewidth(2)    # Increase the top axis thickness
ax.spines['right'].set_linewidth(2)  # Increase the right axis thickness
ax.spines['left'].set_linewidth(2)   # Increase the left axis thickness
ax.spines['bottom'].set_linewidth(2) # Increase the bottom axis thickness
ax.spines['left'].set_color('fuchsia')  # Set the color of the spines to white
ax.spines['bottom'].set_color('fuchsia')  # Set the color of the spines to white

# Customize axis labels
ax.set_xlabel("Educational Qualifications", fontsize=12, color='white')  # Set x-axis label color and size
ax.set_ylabel("Count", fontsize=12, color='white')   # Set y-axis label color and size


# Rotate x-axis labels for better readability
plt.xticks(rotation=90, color="white")  # Make x-tick labels white


# Show the plot
plt.show();

# %%
# Create the countplot with a specific color palette
sns.set_palette("inferno")  


# Create the figure and axis to have more control over the plot's layout and properties
fig, ax = plt.subplots()


# Set the figure and axis background color to black
fig.patch.set_facecolor('black')  # Set the figure's background color to black
ax.set_facecolor('black')         # Set the chart area's background color to black


# Create the countplot on the given axis
sns.countplot(x = "feedback", 
              data = df_onlinefoods,
              edgecolor = 'yellow',
              color = '#f9e68b',
              ax = ax)


# Customize the axis appearance
ax.tick_params(colors='fuchsia')       # Set the tick colors to white for visibility

ax.spines['top'].set_linewidth(2)    # Increase the top axis thickness
ax.spines['right'].set_linewidth(2)  # Increase the right axis thickness
ax.spines['left'].set_linewidth(2)   # Increase the left axis thickness
ax.spines['bottom'].set_linewidth(2) # Increase the bottom axis thickness
ax.spines['left'].set_color('fuchsia')  # Set the color of the spines to white
ax.spines['bottom'].set_color('fuchsia')  # Set the color of the spines to white

# Customize axis labels
ax.set_xlabel("Feedback", fontsize=12, color='white')  # Set x-axis label color and size
ax.set_ylabel("Count", fontsize=12, color='white')   # Set y-axis label color and size


# Rotate x-axis labels for better readability
plt.xticks(rotation=90, color="white")  # Make x-tick labels white


# Show the plot
plt.show();
